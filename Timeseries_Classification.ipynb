# %% [markdown]
# ### Connect to Drive

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive/My Drive/Deep Learning Polimi/6 Time Series
# Out:
# /gdrive/My Drive/Deep Learning Polimi/6 Time Series

# %% [markdown]
# ### Import libraries

# %%
import tensorflow as tf
import numpy as np
import os
import random
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
plt.rc('font', size=16) 
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')
tf.get_logger().setLevel('ERROR')

tfk = tf.keras
tfkl = tf.keras.layers
print(tf.__version__)
# Out:
# 2.7.0

# %% [markdown]
# ### Set seed for reproducibility

# %%
# Random seed for reproducibility
seed = 42

random.seed(seed)
os.environ['PYTHONHASHSEED'] = str(seed)
np.random.seed(seed)
tf.random.set_seed(seed)
tf.compat.v1.set_random_seed(seed)

# %% [markdown]
# ### Exploration Data Analysis (EDA)
# #### Human Activity Recognition

# %% [markdown]
# Load and clean the dataset

# %%
# !gdown --id 152sWECukjvLerrVG2NUO8gtMFg83RKCF --output WISDM_ar_latest.tar.gz
# !tar -xvf WISDM_ar_latest.tar.gz
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=152sWECukjvLerrVG2NUO8gtMFg83RKCF
# To: /gdrive/MyDrive/Deep Learning Polimi/6 Time Series/WISDM_ar_latest.tar.gz
# 100% 11.4M/11.4M [00:00<00:00, 105MB/s]
# WISDM_ar_v1.1/
# WISDM_ar_v1.1/readme.txt
# WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt
# WISDM_ar_v1.1/WISDM_ar_v1.1_raw_about.txt
# WISDM_ar_v1.1/WISDM_ar_v1.1_transformed.arff
# WISDM_ar_v1.1/WISDM_ar_v1.1_trans_about.txt

# %%
column_names = ['user_id', 'activity', 'timestamp', 'x_axis', 'y_axis', 'z_axis']

df = pd.read_csv('WISDM_ar_v1.1/WISDM_ar_v1.1_raw.txt', header=None, names=column_names)
df.z_axis.replace(regex=True, inplace=True, to_replace=r';', value=r'')
df['z_axis'] = df.z_axis.astype(np.float64)
df.dropna(axis=0, how='any', inplace=True)

# %%
print(df.shape)
df.head(10)
# Out:
# (1098203, 6)
#    user_id activity       timestamp    x_axis     y_axis    z_axis
# 0       33  Jogging  49105962326000 -0.694638  12.680544  0.503953
# 1       33  Jogging  49106062271000  5.012288  11.264028  0.953424
# 2       33  Jogging  49106112167000  4.903325  10.882658 -0.081722
# 3       33  Jogging  49106222305000 -0.612916  18.496431  3.023717
# 4       33  Jogging  49106332290000 -1.184970  12.108489  7.205164
# 5       33  Jogging  49106442306000  1.375655  -2.492524 -6.510526
# 6       33  Jogging  49106542312000 -0.612916  10.569390  5.706926
# 7       33  Jogging  49106652389000 -0.503953  13.947236  7.055340
# 8       33  Jogging  49106762313000 -8.430995  11.413852  5.134871
# 9       33  Jogging  49106872299000  0.953424   1.375655  1.648062

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1098203 entries, 0 to 1098203
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   user_id    1098203 non-null  int64
#  1   activity   1098203 non-null  object
#  2   timestamp  1098203 non-null  int64
#  3   x_axis     1098203 non-null  float64
#  4   y_axis     1098203 non-null  float64
#  5   z_axis     1098203 non-null  float64
# dtypes: float64(3), int64(2), object(1)
# memory usage: 58.7+ MB

# %%
# Inspect activities timestamps
plt.figure(figsize=(17,5))
sns.countplot(x = 'activity', data = df, order = df.activity.value_counts().index)
plt.title('Activity Timestamps')
plt.show()

# %%
# Inspect users timestamps
plt.figure(figsize=(17,5))
sns.countplot(x = 'user_id', data = df)
plt.title('Per User Timestamps')
plt.show()

# %%
def inspect_activity(activity, df):
    data = df[df['activity'] == activity][['x_axis', 'y_axis', 'z_axis']][:500]
    axis = data.plot(subplots=True, figsize=(17, 9), title=activity)
    for ax in axis:
        ax.legend(loc='lower right')

# %%
inspect_activity("Walking", df)

# %%
inspect_activity("Standing", df)

# %% [markdown]
# ### Preprocessing

# %%
# Identify single activities per user
df['id'] = df['user_id'].astype('str') + '_' + df['activity'].astype('str')
print('The dataset is composed by {} different activity executions'.format(df['id'].nunique()))

plt.figure(figsize=(17,5))
sns.countplot(x = 'id', data = df, order = df.id.value_counts().index)
plt.title('Per Id Timestamps')
plt.xticks([], [])
plt.show()
# Out:
# The dataset is composed by 179 different activity executions

# %%
df.head()
# Out:
#    user_id activity       timestamp    x_axis     y_axis    z_axis          id
# 0       33  Jogging  49105962326000 -0.694638  12.680544  0.503953  33_Jogging
# 1       33  Jogging  49106062271000  5.012288  11.264028  0.953424  33_Jogging
# 2       33  Jogging  49106112167000  4.903325  10.882658 -0.081722  33_Jogging
# 3       33  Jogging  49106222305000 -0.612916  18.496431  3.023717  33_Jogging
# 4       33  Jogging  49106332290000 -1.184970  12.108489  7.205164  33_Jogging

# %% [markdown]
# Split, Encode and Normalize

# %%
# Split over users
df_train = df[df['user_id'] <= 30]
df_test = df[df['user_id'] > 30]
df_train.shape, df_test.shape
# Out:
# ((898360, 7), (199843, 7))

# %%
# Training users split
training_labels = {
    'Walking': 0,
    'Jogging': 0,
    'Upstairs': 0,
    'Downstairs': 0,
    'Sitting': 0,
    'Standing': 0
}
for id in df_train['id'].unique():
    label = df_train[df_train['id'] == id]['activity'].values[0]
    training_labels[label] += 1
print('Training labels:',training_labels)
# Out:
# Training labels: {'Walking': 30, 'Jogging': 26, 'Upstairs': 27, 'Downstairs': 27, 'Sitting': 17, 'Standing': 18}

# %%
# Test users split
test_labels = {
    'Walking': 0,
    'Jogging': 0,
    'Upstairs': 0,
    'Downstairs': 0,
    'Sitting': 0,
    'Standing': 0
}
for id in df_test['id'].unique():
    label = df_test[df_test['id'] == id]['activity'].values[0]
    test_labels[label] += 1
print('Test labels:',test_labels)
# Out:
# Test labels: {'Walking': 6, 'Jogging': 6, 'Upstairs': 5, 'Downstairs': 5, 'Sitting': 6, 'Standing': 6}

# %%
# Map activities to integers
label_mapping = {
    'Walking': 0,
    'Jogging': 1,
    'Upstairs': 2,
    'Downstairs': 3,
    'Sitting': 4,
    'Standing': 5
}

df_train['activity'] = df_train['activity'].map(label_mapping)
df_test['activity'] = df_test['activity'].map(label_mapping)

# %%
# Apply MinMaxScaler to the useful features
scale_columns = ['x_axis', 'y_axis', 'z_axis']
scaler = MinMaxScaler()
scaler = scaler.fit(df_train[scale_columns])

df_train.loc[:, scale_columns] = scaler.transform(df_train[scale_columns].to_numpy())
df_test.loc[:, scale_columns] = scaler.transform(df_test[scale_columns].to_numpy())

# %%
df_train.head()
# Out:
#       user_id  activity       timestamp  ...    y_axis    z_axis          id
# 8489       17         0  57869902574000  ...  0.741908  0.488932  17_Walking
# 8490       17         0  57870012316000  ...  0.751526  0.487895  17_Walking
# 8491       17         0  57870122301000  ...  0.742938  0.484785  17_Walking
# 8492       17         0  57870222246000  ...  0.748778  0.489623  17_Walking
# 8493       17         0  57870332292000  ...  0.750496  0.486858  17_Walking
#
# [5 rows x 7 columns]

# %%
window = 200
stride = 50

# %%
def build_sequences(df, window=200, stride=200):
    # Sanity check to avoid runtime errors
    assert window % stride == 0
    dataset = []
    labels = []
    for id in df['id'].unique():
        # Take only meaningful features
        temp = df[df['id'] == id][['x_axis','y_axis','z_axis']].values
        # Save the label
        label = df[df['id'] == id]['activity'].values[0]
        # Compute padding length
        padding_len = window - len(temp)%window
        # Create padding and concatenate it
        padding = np.zeros((padding_len,3), dtype='float64')
        temp = np.concatenate((temp,padding))
        # Build features windows with their corresponging labels
        idx = 0
        while idx+window <= len(temp):
            dataset.append(temp[idx:idx+window])
            labels.append(label)
            idx += stride
    dataset = np.array(dataset)
    labels = np.array(labels)
    return dataset, labels

# %%
X_train, y_train = build_sequences(df_train, window, stride)
X_test, y_test = build_sequences(df_test, window, stride)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((17837, 200, 3), (17837,), (3966, 200, 3), (3966,))

# %%
# Convert the sparse labels to categorical values
y_train = tfk.utils.to_categorical(y_train)
y_test = tfk.utils.to_categorical(y_test)
X_train.shape, y_train.shape, X_test.shape, y_test.shape
# Out:
# ((17837, 200, 3), (17837, 6), (3966, 200, 3), (3966, 6))

# %% [markdown]
# ### Build and train models

# %%
input_shape = X_train.shape[1:]
classes = y_train.shape[-1]
batch_size = 128
epochs = 200

# %% [markdown]
# #### Vanilla Long Short Term Memory (LSTM) Neural Network
#
# ![](https://drive.google.com/uc?export=view&id=1FZ_P4SgVAA_mCZQ0tK18VwRqGqzNANOE
# )

# %%
def build_LSTM_classifier(input_shape, classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    lstm = tfkl.LSTM(128, return_sequences=True)(input_layer)
    lstm = tfkl.LSTM(128)(lstm)
    dropout = tfkl.Dropout(.5, seed=seed)(lstm)

    # Classifier
    classifier = tfkl.Dense(128, activation='relu')(dropout)
    output_layer = tfkl.Dense(classes, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_LSTM_classifier(input_shape, classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 200, 3)]          0
#
#  lstm (LSTM)                 (None, 200, 128)          67584
#
#  lstm_1 (LSTM)               (None, 128)               131584
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense (Dense)               (None, 128)               16512
#
#  dense_1 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 216,454
# Trainable params: 216,454
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 126/126 [==============================] - 188s 1s/step - loss: 1.3867 - accuracy: 0.4577 - val_loss: 1.2424 - val_accuracy: 0.6110 - lr: 0.0010
# Epoch 2/200
# 126/126 [==============================] - 167s 1s/step - loss: 1.3104 - accuracy: 0.5067 - val_loss: 1.3768 - val_accuracy: 0.5067 - lr: 0.0010
# Epoch 3/200
# 126/126 [==============================] - 168s 1s/step - loss: 1.3225 - accuracy: 0.4812 - val_loss: 1.2079 - val_accuracy: 0.6155 - lr: 0.0010
# Epoch 4/200
# 126/126 [==============================] - 167s 1s/step - loss: 1.2736 - accuracy: 0.5236 - val_loss: 1.1080 - val_accuracy: 0.6760 - lr: 0.0010
# Epoch 5/200
# 126/126 [==============================] - 168s 1s/step - loss: 1.2390 - accuracy: 0.5408 - val_loss: 1.1345 - val_accuracy: 0.6833 - lr: 0.0010
# Epoch 6/200
# 126/126 [==============================] - 168s 1s/step - loss: 1.1656 - accuracy: 0.5816 - val_loss: 1.1072 - val_accuracy: 0.6351 - lr: 0.0010
# Epoch 7/200
# 126/126 [==============================] - 180s 1s/step - loss: 1.1834 - accuracy: 0.5637 - val_loss: 1.4610 - val_accuracy: 0.3217 - lr: 0.0010
# Epoch 8/200
# 126/126 [==============================] - 169s 1s/step - loss: 1.3992 - accuracy: 0.4566 - val_loss: 1.2088 - val_accuracy: 0.6906 - lr: 0.0010
# Epoch 9/200
# 126/126 [==============================] - 167s 1s/step - loss: 1.1568 - accuracy: 0.5925 - val_loss: 1.6438 - val_accuracy: 0.6435 - lr: 0.0010
# Epoch 10/200
# 126/126 [==============================] - 168s 1s/step - loss: 1.0858 - accuracy: 0.6163 - val_loss: 1.0845 - val_accuracy: 0.6401 - lr: 0.0010
# Epoch 11/200
# 126/126 [==============================] - 169s 1s/step - loss: 1.0029 - accuracy: 0.6459 - val_loss: 0.9720 - val_accuracy: 0.7377 - lr: 0.0010
# Epoch 12/200
# 126/126 [==============================] - 168s 1s/step - loss: 1.1612 - accuracy: 0.5879 - val_loss: 1.1120 - val_accuracy: 0.6530 - lr: 0.0010
# Epoch 13/200
# 126/126 [==============================] - 175s 1s/step - loss: 0.9502 - accuracy: 0.6670 - val_loss: 0.9696 - val_accuracy: 0.7158 - lr: 0.0010
# Epoch 14/200
# 126/126 [==============================] - 168s 1s/step - loss: 0.8305 - accuracy: 0.7115 - val_loss: 1.0916 - val_accuracy: 0.6452 - lr: 0.0010
# Epoch 15/200
# 126/126 [==============================] - 167s 1s/step - loss: 0.8415 - accuracy: 0.7092 - val_loss: 0.9598 - val_accuracy: 0.6844 - lr: 0.0010
# Epoch 16/200
# 126/126 [==============================] - 164s 1s/step - loss: 0.7230 - accuracy: 0.7468 - val_loss: 1.1210 - val_accuracy: 0.6570 - lr: 0.0010
# Epoch 17/200
# 126/126 [==============================] - 166s 1s/step - loss: 0.6538 - accuracy: 0.7615 - val_loss: 1.1270 - val_accuracy: 0.6401 - lr: 5.0000e-04
# Epoch 18/200
# 126/126 [==============================] - 168s 1s/step - loss: 0.6103 - accuracy: 0.7817 - val_loss: 0.9897 - val_accuracy: 0.6233 - lr: 5.0000e-04
# Epoch 19/200
# 126/126 [==============================] - 166s 1s/step - loss: 0.5958 - accuracy: 0.7854 - val_loss: 1.0983 - val_accuracy: 0.6850 - lr: 5.0000e-04
# Epoch 20/200
# 126/126 [==============================] - 163s 1s/step - loss: 0.5727 - accuracy: 0.7937 - val_loss: 1.2331 - val_accuracy: 0.6300 - lr: 5.0000e-04
# Epoch 21/200
# 126/126 [==============================] - 164s 1s/step - loss: 0.5687 - accuracy: 0.7972 - val_loss: 0.9414 - val_accuracy: 0.7096 - lr: 5.0000e-04

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save('LSTM')
# model = tfk.models.load_model('LSTM')

# %%
# Predict the test set with the LSTM
predictions = model.predict(X_test)
predictions.shape
# Out:
# (3966, 6)

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.5441
# Precision: 0.1957
# Recall: 0.2605
# F1: 0.2131

# %% [markdown]
# #### Bidirectional Long Short Term Memory (BiLSTM) Neural Network
#
# ![](https://drive.google.com/uc?export=view&id=1CN-jJqzb5AurhnMMiuvdVCaPGy2KReLc
# )

# %%
def build_BiLSTM_classifier(input_shape, classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    bilstm = tfkl.Bidirectional(tfkl.LSTM(128, return_sequences=True))(input_layer)
    bilstm = tfkl.Bidirectional(tfkl.LSTM(128))(bilstm)
    dropout = tfkl.Dropout(.5, seed=seed)(bilstm)

    # Classifier
    classifier = tfkl.Dense(128, activation='relu')(dropout)
    output_layer = tfkl.Dense(classes, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_BiLSTM_classifier(input_shape, classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 200, 3)]          0
#
#  bidirectional (Bidirectiona  (None, 200, 256)         135168
#  l)
#
#  bidirectional_1 (Bidirectio  (None, 256)              394240
#  nal)
#
#  dropout_1 (Dropout)         (None, 256)               0
#
#  dense_2 (Dense)             (None, 128)               32896
#
#  dense_3 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 563,078
# Trainable params: 563,078
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 126/126 [==============================] - 435s 3s/step - loss: 1.3792 - accuracy: 0.4594 - val_loss: 1.1372 - val_accuracy: 0.6345 - lr: 0.0010
# Epoch 2/200
# 126/126 [==============================] - 412s 3s/step - loss: 1.2586 - accuracy: 0.5219 - val_loss: 1.0517 - val_accuracy: 0.6833 - lr: 0.0010
# Epoch 3/200
# 126/126 [==============================] - 404s 3s/step - loss: 1.2031 - accuracy: 0.5479 - val_loss: 1.0883 - val_accuracy: 0.6911 - lr: 0.0010
# Epoch 4/200
# 126/126 [==============================] - 414s 3s/step - loss: 1.1845 - accuracy: 0.5578 - val_loss: 1.2127 - val_accuracy: 0.6771 - lr: 0.0010
# Epoch 5/200
# 126/126 [==============================] - 400s 3s/step - loss: 1.2148 - accuracy: 0.5562 - val_loss: 1.2620 - val_accuracy: 0.6216 - lr: 0.0010
# Epoch 6/200
# 126/126 [==============================] - 395s 3s/step - loss: 1.1889 - accuracy: 0.5561 - val_loss: 1.2982 - val_accuracy: 0.5992 - lr: 0.0010
# Epoch 7/200
# 126/126 [==============================] - 394s 3s/step - loss: 1.1221 - accuracy: 0.5971 - val_loss: 1.1340 - val_accuracy: 0.7158 - lr: 0.0010
# Epoch 8/200
# 126/126 [==============================] - 370s 3s/step - loss: 1.0411 - accuracy: 0.6327 - val_loss: 1.1522 - val_accuracy: 0.6160 - lr: 0.0010
# Epoch 9/200
# 126/126 [==============================] - 374s 3s/step - loss: 0.8354 - accuracy: 0.7169 - val_loss: 0.9116 - val_accuracy: 0.6726 - lr: 0.0010
# Epoch 10/200
# 126/126 [==============================] - 400s 3s/step - loss: 0.9647 - accuracy: 0.6668 - val_loss: 0.9569 - val_accuracy: 0.7186 - lr: 0.0010
# Epoch 11/200
# 126/126 [==============================] - 421s 3s/step - loss: 0.9535 - accuracy: 0.6822 - val_loss: 1.3412 - val_accuracy: 0.5146 - lr: 0.0010
# Epoch 12/200
# 126/126 [==============================] - 430s 3s/step - loss: 1.2122 - accuracy: 0.5715 - val_loss: 1.0905 - val_accuracy: 0.6155 - lr: 0.0010
# Epoch 13/200
# 126/126 [==============================] - 421s 3s/step - loss: 1.0010 - accuracy: 0.6446 - val_loss: 0.9896 - val_accuracy: 0.6474 - lr: 0.0010
# Epoch 14/200
# 126/126 [==============================] - 398s 3s/step - loss: 0.8775 - accuracy: 0.6818 - val_loss: 0.8125 - val_accuracy: 0.7567 - lr: 0.0010
# Epoch 15/200
# 126/126 [==============================] - 402s 3s/step - loss: 0.7835 - accuracy: 0.7250 - val_loss: 0.7172 - val_accuracy: 0.7859 - lr: 0.0010
# Epoch 16/200
# 126/126 [==============================] - 403s 3s/step - loss: 1.0369 - accuracy: 0.6311 - val_loss: 1.4350 - val_accuracy: 0.3380 - lr: 0.0010
# Epoch 17/200
# 126/126 [==============================] - 418s 3s/step - loss: 1.3720 - accuracy: 0.4828 - val_loss: 1.2690 - val_accuracy: 0.4277 - lr: 0.0010
# Epoch 18/200
# 126/126 [==============================] - 403s 3s/step - loss: 1.1426 - accuracy: 0.5965 - val_loss: 0.9898 - val_accuracy: 0.6788 - lr: 0.0010
# Epoch 19/200
# 126/126 [==============================] - 403s 3s/step - loss: 1.0759 - accuracy: 0.6301 - val_loss: 0.8927 - val_accuracy: 0.7209 - lr: 0.0010
# Epoch 20/200
# 126/126 [==============================] - 401s 3s/step - loss: 0.9650 - accuracy: 0.6707 - val_loss: 0.9658 - val_accuracy: 0.7074 - lr: 0.0010
# Epoch 21/200
# 126/126 [==============================] - 401s 3s/step - loss: 0.9113 - accuracy: 0.6869 - val_loss: 0.8973 - val_accuracy: 0.7248 - lr: 5.0000e-04
# Epoch 22/200
# 126/126 [==============================] - 395s 3s/step - loss: 0.8636 - accuracy: 0.7020 - val_loss: 0.9776 - val_accuracy: 0.7012 - lr: 5.0000e-04
# Epoch 23/200
# 126/126 [==============================] - 388s 3s/step - loss: 0.8380 - accuracy: 0.7117 - val_loss: 0.9469 - val_accuracy: 0.6827 - lr: 5.0000e-04
# Epoch 24/200
# 126/126 [==============================] - 395s 3s/step - loss: 0.8281 - accuracy: 0.7133 - val_loss: 0.9202 - val_accuracy: 0.7550 - lr: 5.0000e-04
# Epoch 25/200
# 126/126 [==============================] - 399s 3s/step - loss: 0.7673 - accuracy: 0.7333 - val_loss: 0.8137 - val_accuracy: 0.7651 - lr: 5.0000e-04

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save('BiLSTM')
# model = tfk.models.load_model('BiLSTM')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.
# WARNING:absl:Found untraced functions such as lstm_cell_16_layer_call_fn, lstm_cell_16_layer_call_and_return_conditional_losses, lstm_cell_17_layer_call_fn, lstm_cell_17_layer_call_and_return_conditional_losses, lstm_cell_19_layer_call_fn while saving (showing 5 of 20). These functions will not be directly callable after loading.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe54a106410> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe54a112e10> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe548bd9cd0> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.
# WARNING:absl:<keras.layers.recurrent.LSTMCell object at 0x7fe547c62690> has the same name 'LSTMCell' as a built-in Keras object. Consider renaming <class 'keras.layers.recurrent.LSTMCell'> to avoid naming conflicts when loading with `tf.keras.models.load_model`. If renaming is not possible, pass the object in the `custom_objects` parameter of the load function.

# %%
# Predict the test set with the BiLSTM
predictions = model.predict(X_test)
predictions.shape
# Out:
# (3966, 6)

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.7113
# Precision: 0.6347
# Recall: 0.5612
# F1: 0.5742

# %% [markdown]
# #### 1D Convolutional Neural Network
#
# ![](https://drive.google.com/uc?export=view&id=10B7c-F58-eNr6CP7D_UZeVp0gTeYMrFQ
# )

# %%
def build_1DCNN_classifier(input_shape, classes):
    # Build the neural network layer by layer
    input_layer = tfkl.Input(shape=input_shape, name='Input')

    # Feature extractor
    cnn = tfkl.Conv1D(128,3,padding='same',activation='relu')(input_layer)
    cnn = tfkl.MaxPooling1D()(cnn)
    cnn = tfkl.Conv1D(128,3,padding='same',activation='relu')(cnn)
    gap = tfkl.GlobalAveragePooling1D()(cnn)
    dropout = tfkl.Dropout(.5, seed=seed)(gap)

    # Classifier
    classifier = tfkl.Dense(128, activation='relu')(dropout)
    output_layer = tfkl.Dense(classes, activation='softmax')(classifier)

    # Connect input and output through the Model class
    model = tfk.Model(inputs=input_layer, outputs=output_layer, name='model')

    # Compile the model
    model.compile(loss=tfk.losses.CategoricalCrossentropy(), optimizer=tfk.optimizers.Adam(), metrics='accuracy')

    # Return the model
    return model

# %%
model = build_1DCNN_classifier(input_shape, classes)
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  Input (InputLayer)          [(None, 200, 3)]          0
#
#  conv1d (Conv1D)             (None, 200, 128)          1280
#
#  max_pooling1d (MaxPooling1D  (None, 100, 128)         0
#  )
#
#  conv1d_1 (Conv1D)           (None, 100, 128)          49280
#
#  global_average_pooling1d (G  (None, 128)              0
#  lobalAveragePooling1D)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 128)               16512
#
#  dense_5 (Dense)             (None, 6)                 774
#
# =================================================================
# Total params: 67,846
# Trainable params: 67,846
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(
    x = X_train,
    y = y_train,
    batch_size = batch_size,
    epochs = epochs,
    validation_split=.1,
    callbacks = [
        tfk.callbacks.EarlyStopping(monitor='val_accuracy', mode='max', patience=10, restore_best_weights=True),
        tfk.callbacks.ReduceLROnPlateau(monitor='val_accuracy', mode='max', patience=5, factor=0.5, min_lr=1e-5)
    ]
).history
# Out:
# Epoch 1/200
# 126/126 [==============================] - 20s 150ms/step - loss: 1.1908 - accuracy: 0.5767 - val_loss: 0.7493 - val_accuracy: 0.7517 - lr: 0.0010
# Epoch 2/200
# 126/126 [==============================] - 19s 149ms/step - loss: 0.7356 - accuracy: 0.7412 - val_loss: 0.5267 - val_accuracy: 0.8419 - lr: 0.0010
# Epoch 3/200
# 126/126 [==============================] - 19s 150ms/step - loss: 0.6159 - accuracy: 0.7707 - val_loss: 0.4952 - val_accuracy: 0.8380 - lr: 0.0010
# Epoch 4/200
# 126/126 [==============================] - 19s 150ms/step - loss: 0.5814 - accuracy: 0.7795 - val_loss: 0.5939 - val_accuracy: 0.8161 - lr: 0.0010
# Epoch 5/200
# 126/126 [==============================] - 19s 150ms/step - loss: 0.5435 - accuracy: 0.7910 - val_loss: 0.4608 - val_accuracy: 0.8363 - lr: 0.0010
# Epoch 6/200
# 126/126 [==============================] - 19s 147ms/step - loss: 0.5268 - accuracy: 0.7980 - val_loss: 0.5628 - val_accuracy: 0.8089 - lr: 0.0010
# Epoch 7/200
# 126/126 [==============================] - 19s 147ms/step - loss: 0.5021 - accuracy: 0.8042 - val_loss: 0.4692 - val_accuracy: 0.8268 - lr: 0.0010
# Epoch 8/200
# 126/126 [==============================] - 19s 148ms/step - loss: 0.4729 - accuracy: 0.8175 - val_loss: 0.5084 - val_accuracy: 0.8240 - lr: 5.0000e-04
# Epoch 9/200
# 126/126 [==============================] - 19s 147ms/step - loss: 0.4605 - accuracy: 0.8211 - val_loss: 0.4561 - val_accuracy: 0.8324 - lr: 5.0000e-04
# Epoch 10/200
# 126/126 [==============================] - 19s 148ms/step - loss: 0.4455 - accuracy: 0.8275 - val_loss: 0.5072 - val_accuracy: 0.8184 - lr: 5.0000e-04
# Epoch 11/200
# 126/126 [==============================] - 19s 148ms/step - loss: 0.4399 - accuracy: 0.8283 - val_loss: 0.4632 - val_accuracy: 0.8380 - lr: 5.0000e-04
# Epoch 12/200
# 126/126 [==============================] - 19s 148ms/step - loss: 0.4248 - accuracy: 0.8322 - val_loss: 0.4556 - val_accuracy: 0.8430 - lr: 5.0000e-04
# Epoch 13/200
# 126/126 [==============================] - 19s 149ms/step - loss: 0.4077 - accuracy: 0.8397 - val_loss: 0.4074 - val_accuracy: 0.8419 - lr: 5.0000e-04
# Epoch 14/200
# 126/126 [==============================] - 19s 149ms/step - loss: 0.4011 - accuracy: 0.8415 - val_loss: 0.4123 - val_accuracy: 0.8380 - lr: 5.0000e-04
# Epoch 15/200
# 126/126 [==============================] - 19s 151ms/step - loss: 0.3850 - accuracy: 0.8457 - val_loss: 0.4465 - val_accuracy: 0.8369 - lr: 5.0000e-04
# Epoch 16/200
# 126/126 [==============================] - 19s 151ms/step - loss: 0.3742 - accuracy: 0.8517 - val_loss: 0.4623 - val_accuracy: 0.8498 - lr: 5.0000e-04
# Epoch 17/200
# 126/126 [==============================] - 19s 153ms/step - loss: 0.3675 - accuracy: 0.8534 - val_loss: 0.4020 - val_accuracy: 0.8767 - lr: 5.0000e-04
# Epoch 18/200
# 126/126 [==============================] - 19s 150ms/step - loss: 0.3643 - accuracy: 0.8529 - val_loss: 0.3859 - val_accuracy: 0.8756 - lr: 5.0000e-04
# Epoch 19/200
# 126/126 [==============================] - 19s 149ms/step - loss: 0.3489 - accuracy: 0.8603 - val_loss: 0.3556 - val_accuracy: 0.8711 - lr: 5.0000e-04
# Epoch 20/200
# 126/126 [==============================] - 19s 152ms/step - loss: 0.3507 - accuracy: 0.8630 - val_loss: 0.4551 - val_accuracy: 0.8341 - lr: 5.0000e-04
# Epoch 21/200
# 126/126 [==============================] - 19s 150ms/step - loss: 0.3334 - accuracy: 0.8682 - val_loss: 0.3700 - val_accuracy: 0.8694 - lr: 5.0000e-04
# Epoch 22/200
# 126/126 [==============================] - 19s 150ms/step - loss: 0.3158 - accuracy: 0.8735 - val_loss: 0.3569 - val_accuracy: 0.8677 - lr: 5.0000e-04
# Epoch 23/200
# 126/126 [==============================] - 18s 147ms/step - loss: 0.3041 - accuracy: 0.8808 - val_loss: 0.3431 - val_accuracy: 0.8660 - lr: 2.5000e-04
# Epoch 24/200
# 126/126 [==============================] - 19s 147ms/step - loss: 0.3031 - accuracy: 0.8785 - val_loss: 0.3711 - val_accuracy: 0.8677 - lr: 2.5000e-04
# Epoch 25/200
# 126/126 [==============================] - 18s 146ms/step - loss: 0.2964 - accuracy: 0.8830 - val_loss: 0.3675 - val_accuracy: 0.8733 - lr: 2.5000e-04
# Epoch 26/200
# 126/126 [==============================] - 18s 146ms/step - loss: 0.2917 - accuracy: 0.8843 - val_loss: 0.3567 - val_accuracy: 0.8739 - lr: 2.5000e-04
# Epoch 27/200
# 126/126 [==============================] - 18s 144ms/step - loss: 0.2937 - accuracy: 0.8833 - val_loss: 0.4761 - val_accuracy: 0.8459 - lr: 2.5000e-04

# %%
best_epoch = np.argmax(history['val_accuracy'])
plt.figure(figsize=(17,4))
plt.plot(history['loss'], label='Training loss', alpha=.8, color='#ff7f0e')
plt.plot(history['val_loss'], label='Validation loss', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Categorical Crossentropy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(17,4))
plt.plot(history['accuracy'], label='Training accuracy', alpha=.8, color='#ff7f0e')
plt.plot(history['val_accuracy'], label='Validation accuracy', alpha=.9, color='#5a9aa5')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.title('Accuracy')
plt.legend()
plt.grid(alpha=.3)
plt.show()

plt.figure(figsize=(18,3))
plt.plot(history['lr'], label='Learning Rate', alpha=.8, color='#ff7f0e')
plt.axvline(x=best_epoch, label='Best epoch', alpha=.3, ls='--', color='#5a9aa5')
plt.legend()
plt.grid(alpha=.3)
plt.show()

# %%
model.save('1DCNN')
# model = tfk.models.load_model('1DCNN')
# Out:
# WARNING:absl:Function `_wrapped_model` contains input name(s) Input with unsupported characters which will be renamed to input in the SavedModel.

# %%
# Predict the test set with the 1DCNN
predictions = model.predict(X_test)
predictions.shape
# Out:
# (3966, 6)

# %%
# Compute the confusion matrix
cm = confusion_matrix(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))

# Compute the classification metrics
accuracy = accuracy_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1))
precision = precision_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
recall = recall_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
f1 = f1_score(np.argmax(y_test, axis=-1), np.argmax(predictions, axis=-1), average='macro')
print('Accuracy:',accuracy.round(4))
print('Precision:',precision.round(4))
print('Recall:',recall.round(4))
print('F1:',f1.round(4))

# Plot the confusion matrix
plt.figure(figsize=(10,8))
sns.heatmap(cm.T, cmap='Blues', xticklabels=list(label_mapping.keys()), yticklabels=list(label_mapping.keys()))
plt.xlabel('True labels')
plt.ylabel('Predicted labels')
plt.show()
# Out:
# Accuracy: 0.8601
# Precision: 0.7636
# Recall: 0.79
# F1: 0.7726

# %% [markdown]
# Damn, once again no free lunch
